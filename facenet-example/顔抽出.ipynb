# %%
# -*- coding:utf-8 -*-
import cv2
import numpy as np

# OpenCVのデフォルトの分類器のpath。(https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xmlのファイルを使う)
cascade_path = './haarcascade_frontalface_default.xml'
faceCascade = cv2.CascadeClassifier(cascade_path)

# %%
# 顔認識する対象を決定（検索ワードを入力）
SearchName = ["arimura","haru","hasimoto","tsuchiya"]
# 画像の取得枚数の上限
ImgNumber =600
# CNNで学習するときの画像のサイズを設定（サイズが大きいと学習に時間がかかる）
ImgSize=(250,250)
input_shape=(250,250,3)

# %%
import os
# オリジナル画像用のフォルダ
os.makedirs("./Original", exist_ok=True)
# 顔の画像用のフォルダ
os.makedirs("./Face", exist_ok=True)
# ImgSizeで設定したサイズに編集された顔画像用のフォルダ
os.makedirs("./FaceEdited", exist_ok=True)
# テストデータを入れる用のフォルダ
os.makedirs("./test", exist_ok=True)

# %%
for name in SearchName:   
    # 画像データのあるディレクトリ
    input_data_path = "data_path"+str(name)
    print(input_data_path)
    # 切り抜いた画像の保存先ディレクトリを作成
    os.makedirs("./Face/"+str(name)+"_face", exist_ok=True)
    save_path = "./Face/"+str(name)+"_face/"
    # 収集した画像の枚数(任意で変更)
    image_count = 9
    # 顔検知に成功した数(デフォルトで0を指定)
    face_detect_count = 0

    print("{}の顔を検出し切り取りを開始します。".format(name))
    # 集めた画像データから顔が検知されたら、切り取り、保存する。
    for i in range(image_count):
        print(input_data_path + '\\'+ str(i+1) + '.jpg')
        img = cv2.imread(input_data_path + '\\'+ str(i+1) + '.jpg', cv2.IMREAD_COLOR)
        print(img.shape)
        if img is None:
             print('image' + str(i+1) + ':NoFace')
        else:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            face = faceCascade.detectMultiScale(gray, 1.1, 3)
            if len(face) > 0:
                for rect in face:
                    # 顔認識部分を赤線で囲み保存(今はこの部分は必要ない)
                    # cv2.rectangle(img, tuple(rect[0:2]), tuple(rect[0:2]+rect[2:4]), (0, 0,255), thickness=1)
                    # cv2.imwrite('detected.jpg', img)
                    x = rect[0]
                    y = rect[1]
                    w = rect[2]
                    h = rect[3]
                    cv2.imwrite(save_path + 'cutted' + str(face_detect_count) + '.jpg',img[y:y+h,  x:x+w])
                    face_detect_count = face_detect_count + 1
            else:
                print('image' + str(i) + ':NoFace') 

print("顔画像の切り取り作業、正常に動作しました。")
# Out:
# C:\Users\haya\Desktop\Original\arimura
# arimuraの顔を検出し切り取りを開始します。
# C:\Users\haya\Desktop\Original\arimura\1.jpg
# (225, 225, 3)
# C:\Users\haya\Desktop\Original\arimura\2.jpg
# (225, 225, 3)
# C:\Users\haya\Desktop\Original\arimura\3.jpg
# (191, 264, 3)
# C:\Users\haya\Desktop\Original\arimura\4.jpg
# (225, 225, 3)
# C:\Users\haya\Desktop\Original\arimura\5.jpg
# (225, 225, 3)
# C:\Users\haya\Desktop\Original\arimura\6.jpg
# (195, 259, 3)
# C:\Users\haya\Desktop\Original\arimura\7.jpg
# (183, 275, 3)
# C:\Users\haya\Desktop\Original\arimura\8.jpg
# (183, 275, 3)
# C:\Users\haya\Desktop\Original\arimura\9.jpg
# (195, 259, 3)
# C:\Users\haya\Desktop\Original\haru
# haruの顔を検出し切り取りを開始します。
# C:\Users\haya\Desktop\Original\haru\1.jpg
# (259, 194, 3)
# C:\Users\haya\Desktop\Original\haru\2.jpg
# (275, 183, 3)
# C:\Users\haya\Desktop\Original\haru\3.jpg
# (207, 243, 3)
# C:\Users\haya\Desktop\Original\haru\4.jpg
# (183, 275, 3)
# image3:NoFace
# C:\Users\haya\Desktop\Original\haru\5.jpg
# (259, 194, 3)
# C:\Users\haya\Desktop\Original\haru\6.jpg
# (251, 201, 3)
# C:\Users\haya\Desktop\Original\haru\7.jpg
# (225, 224, 3)
# C:\Users\haya\Desktop\Original\haru\8.jpg
# (168, 300, 3)
# C:\Users\haya\Desktop\Original\haru\9.jpg
# (259, 194, 3)
# C:\Users\haya\Desktop\Original\hasimoto
# hasimotoの顔を検出し切り取りを開始します。
# C:\Users\haya\Desktop\Original\hasimoto\1.jpg
# (168, 300, 3)
# C:\Users\haya\Desktop\Original\hasimoto\2.jpg
# (275, 183, 3)
# C:\Users\haya\Desktop\Original\hasimoto\3.jpg
# (228, 221, 3)
# C:\Users\haya\Desktop\Original\hasimoto\4.jpg
# (185, 272, 3)
# C:\Users\haya\Desktop\Original\hasimoto\5.jpg
# (205, 246, 3)
# C:\Users\haya\Desktop\Original\hasimoto\6.jpg
# (255, 198, 3)
# C:\Users\haya\Desktop\Original\hasimoto\7.jpg
# (183, 275, 3)
# C:\Users\haya\Desktop\Original\hasimoto\8.jpg
# (267, 189, 3)
# C:\Users\haya\Desktop\Original\hasimoto\9.jpg
# (225, 225, 3)
# C:\Users\haya\Desktop\Original\tsuchiya
# tsuchiyaの顔を検出し切り取りを開始します。
# C:\Users\haya\Desktop\Original\tsuchiya\1.jpg
# (225, 225, 3)
# C:\Users\haya\Desktop\Original\tsuchiya\2.jpg
# (194, 260, 3)
# C:\Users\haya\Desktop\Original\tsuchiya\3.jpg
# (225, 225, 3)
# C:\Users\haya\Desktop\Original\tsuchiya\4.jpg
# (268, 188, 3)
# C:\Users\haya\Desktop\Original\tsuchiya\5.jpg
# (257, 196, 3)
# C:\Users\haya\Desktop\Original\tsuchiya\6.jpg
# (264, 191, 3)
# C:\Users\haya\Desktop\Original\tsuchiya\7.jpg
# (275, 183, 3)
# C:\Users\haya\Desktop\Original\tsuchiya\8.jpg
# (202, 249, 3)
# C:\Users\haya\Desktop\Original\tsuchiya\9.jpg
# (183, 275, 3)
# 顔画像の切り取り作業、正常に動作しました。
