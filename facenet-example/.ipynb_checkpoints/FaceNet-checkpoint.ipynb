# %%
from facenet.src import facenet
import tensorflow as tf
import numpy as np
from PIL import Image

class FaceEmbedding(object):

    def __init__(self, model_path):
        # モデルを読み込んでグラフに展開
        facenet.load_model(model_path)

        self.input_image_size = 160
        self.sess = tf.Session()
        self.images_placeholder = tf.get_default_graph().get_tensor_by_name("input:0")
        self.embeddings = tf.get_default_graph().get_tensor_by_name("embeddings:0")
        self.phase_train_placeholder = tf.get_default_graph().get_tensor_by_name("phase_train:0")
        self.embedding_size = self.embeddings.get_shape()[1]

    def __del__(self):
        self.sess.close()

    def load_image(self, image_path, width, height, mode):
        image = Image.open(image_path)
        image = image.resize([width, height], Image.BILINEAR)
        return np.array(image.convert(mode))

    def face_embeddings(self, image_path):
        image = self.load_image(image_path, self.input_image_size, self.input_image_size, 'RGB')
        prewhitened = facenet.prewhiten(image)
        prewhitened = prewhitened.reshape(-1, prewhitened.shape[0], prewhitened.shape[1], prewhitened.shape[2])
        feed_dict = { self.images_placeholder: prewhitened, self.phase_train_placeholder: False }
        embeddings = self.sess.run(self.embeddings, feed_dict=feed_dict)
        return embeddings

# %%
FACE_MEDEL_PATH = './20180402-114759/20180402-114759.pb'
face_embedding = FaceEmbedding(FACE_MEDEL_PATH)
# Out:
# Model filename: ./facenet/src/models/20180402-114759/20180402-114759.pb
# WARNING:tensorflow:From C:\Users\haya\Desktop\facenet-example\facenet\src\facenet.py:371: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# WARNING:tensorflow:From C:\Users\haya\Desktop\facenet-example\facenet\src\facenet.py:372: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.

# %%
print(tf.__version__)
# Out:
# 1.15.0

# %%
import glob
faces_image_paths = glob.glob('./images/*/*.jpg')

# %%
print(faces_image_paths)
# Out:
# ['./images\\arimura_face\\cutted0.jpg', './images\\arimura_face\\cutted1.jpg', './images\\arimura_face\\cutted2.jpg', './images\\arimura_face\\cutted3.jpg', './images\\arimura_face\\cutted4.jpg', './images\\arimura_face\\cutted5.jpg', './images\\arimura_face\\cutted6.jpg', './images\\arimura_face\\cutted7.jpg', './images\\arimura_face\\cutted8.jpg', './images\\haru_face\\cutted0.jpg', './images\\haru_face\\cutted1.jpg', './images\\haru_face\\cutted2.jpg', './images\\haru_face\\cutted3.jpg', './images\\haru_face\\cutted4.jpg', './images\\haru_face\\cutted5.jpg', './images\\haru_face\\cutted6.jpg', './images\\haru_face\\cutted7.jpg', './images\\haru_face\\cutted8.jpg', './images\\hasimoto_face\\cutted0.jpg', './images\\hasimoto_face\\cutted1.jpg', './images\\hasimoto_face\\cutted2.jpg', './images\\hasimoto_face\\cutted3.jpg', './images\\hasimoto_face\\cutted4.jpg', './images\\hasimoto_face\\cutted5.jpg', './images\\hasimoto_face\\cutted7.jpg', './images\\hasimoto_face\\cutted8.jpg', './images\\hasimoto_face\\cutted9.jpg', './images\\tsuchiya_face\\cutted0.jpg', './images\\tsuchiya_face\\cutted1.jpg', './images\\tsuchiya_face\\cutted2.jpg', './images\\tsuchiya_face\\cutted3.jpg', './images\\tsuchiya_face\\cutted4.jpg', './images\\tsuchiya_face\\cutted5.jpg', './images\\tsuchiya_face\\cutted6.jpg', './images\\tsuchiya_face\\cutted7.jpg', './images\\tsuchiya_face\\cutted8.jpg']

# %%
# 顔画像から特徴ベクトルを抽出
features = np.array([face_embedding.face_embeddings(f)[0] for f in faces_image_paths])
print(features.shape)
# Out:
# (36, 512)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(features)
reduced = pca.fit_transform(features)
print(reduced.shape)
# Out:
# (36, 2)

# %%
from sklearn.cluster import KMeans

K = 4
kmeans = KMeans(n_clusters=K).fit(reduced)
pred_label = kmeans.predict(reduced)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# クラスタリングした結果をプロット
x = reduced[:, 0]
y = reduced[:, 1]
plt.scatter(x, y, c=pred_label)
plt.colorbar()
plt.show()

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox 
def imscatter(x, y, image_path, ax=None, zoom=1): 
    if ax is None: 
        ax = plt.gca() 

    artists = [] 
    for x0, y0,image in zip(x, y,image_path): 
        image = plt.imread(image) 
        im = OffsetImage(image, zoom=zoom) 
        ab = AnnotationBbox(im, (x0, y0), xycoords='data', frameon=False) 
        artists.append(ax.add_artist(ab)) 
    return artists

x = reduced[:, 0]
y = reduced[:, 1]
fig, ax = plt.subplots() 
imscatter(x, y, faces_image_paths, ax=ax,  zoom=.2) 
ax.plot(x, y, 'ko',alpha=0) 
ax.autoscale() 
plt.show()
